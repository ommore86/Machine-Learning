# %% [markdown]
# <a href="https://colab.research.google.com/github/ommore86/Machine-Learning/blob/main/ML_8_Logic_Gates_using_MP_Neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
def mp_neuron(x, w, threshold):
    # Calculate weighted sum
    weighted_sum = np.dot(x, w)
    # Apply step activation function
    return 1 if weighted_sum >= threshold else 0

# %%
inputs = np.array([
    [0, 0],
    [0, 1],
    [1, 0],
    [1, 1]
])

# %%
print("AND Gate:")
weights = np.array([1, 1])
threshold = 2

for x in inputs:
    print(f"Input: {x}, Output: {mp_neuron(x, weights, threshold)}")
# Out:
# AND Gate:
# Input: [0 0], Output: 0
# Input: [0 1], Output: 0
# Input: [1 0], Output: 0
# Input: [1 1], Output: 1

# %%
print("\nOR Gate:")
weights = np.array([1, 1])
threshold = 1

for x in inputs:
    print(f"Input: {x}, Output: {mp_neuron(x, weights, threshold)}")
# Out:
# OR Gate:
# Input: [0 0], Output: 0
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 1

# %%
print("\nNAND Gate:")
weights = np.array([-2, -2])
threshold = -3

for x in inputs:
    print(f"Input: {x}, Output: {mp_neuron(x, weights, threshold)}")
# Out:
# NAND Gate:
# Input: [0 0], Output: 1
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 0

# %%
print("\nNOR Gate:")
weights = np.array([-1, -1])
threshold = -1

for x in inputs:
    print(f"Input: {x}, Output: {mp_neuron(x, weights, threshold)}")
# Out:
# NOR Gate:
# Input: [0 0], Output: 1
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 0
